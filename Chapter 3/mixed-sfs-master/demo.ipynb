# %%
import spectralFeatureSelection as sfs
import pandas as pd
import numpy as np

# %%
train = pd.read_table('cmc.data',sep=',',
                      names=['Wife age','Wife education','Husband education','Number of children ever born','Wife religion','Wife now working?' ,'Husband occupation','Standard-of-living index','Media exposure','method'])

# %%
train.head()
# Out:
#    Wife age  Wife education  Husband education  Number of children ever born  \
# 0        24               2                  3                             3
# 1        45               1                  3                            10
# 2        43               2                  3                             7
# 3        42               3                  2                             9
# 4        36               3                  3                             8
#
#    Wife religion  Wife now working?  Husband occupation  \
# 0              1                  1                   2
# 1              1                  1                   3
# 2              1                  1                   3
# 3              1                  1                   3
# 4              1                  1                   3
#
#    Standard-of-living index  Media exposure  method
# 0                         3               0       1
# 1                         4               0       1
# 2                         4               0       1
# 3                         3               0       1
# 4                         2               0       1

# %%
train = train.drop(columns = ['method'])

# %%
featureWeights = sfs.selectFeatures(inData=train , maxNumClusters = 3)
# Out:
# #### Working on base data
#
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
# C:\Users\qq139\python\mixed-sfs-master\spectralFeatureSelection.py:58: ComplexWarning: Casting complex values to real discards the imaginary part
#   eigVals[:,0] = eigVals_current
# #### Feature dropped: 1 out of 9 (time elapsed: 00:00:00)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
# C:\Users\qq139\python\mixed-sfs-master\spectralFeatureSelection.py:82: ComplexWarning: Casting complex values to real discards the imaginary part
#   eigVals[:,(i+1)] = eigVals_current
# #### Feature dropped: 2 out of 9 (time elapsed: 00:00:01)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
#
# #### Feature dropped: 3 out of 9 (time elapsed: 00:00:02)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
#
# #### Feature dropped: 4 out of 9 (time elapsed: 00:00:03)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
#
# #### Feature dropped: 5 out of 9 (time elapsed: 00:00:04)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
#
# #### Feature dropped: 6 out of 9 (time elapsed: 00:00:05)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
#
# #### Feature dropped: 7 out of 9 (time elapsed: 00:00:06)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
#
# #### Feature dropped: 8 out of 9 (time elapsed: 00:00:07)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
#
# #### Feature dropped: 9 out of 9 (time elapsed: 00:00:08)
# # clinicalKernel running on GPU ...
# # Input contains no categorical data
# # Computed similarity matrix (GPU exec time: 00:00:00)
# # Output stored on GPU
#
# # laplacian_normalised running on GPU ...
# # Computed Laplacian (GPU exec time: 00:00:00)
# # Output returned to CPU
#
# # Computing eigenvalues ...
#
# #### Iterations complete
#
#
# # Eigenvalues saved to file eigenValues.csv
#
# # Feature weights saved to file featureWeights.csv
#
# #### Done ####
